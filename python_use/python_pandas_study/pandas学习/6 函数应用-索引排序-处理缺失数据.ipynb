# %% [markdown]
# # 6 Pandas的函数应用

# %%
import pandas as pd
import numpy as np
# Numpy ufunc 函数，randn跟的是维数
df = pd.DataFrame(np.random.randn(5,4) - 1)
print(df)

print(np.abs(df)) #绝对值
# Out:
#           0         1         2         3
# 0 -0.463347 -0.122687 -1.125850 -2.200934
# 1 -0.851347  0.866597 -1.871279 -1.276585
# 2 -0.442345 -1.240374 -0.661011  0.620086
# 3  0.547772 -0.421455  0.193280 -2.177365
# 4 -0.374704 -0.632015  1.116807 -0.833270
#           0         1         2         3
# 0  0.463347  0.122687  1.125850  2.200934
# 1  0.851347  0.866597  1.871279  1.276585
# 2  0.442345  1.240374  0.661011  0.620086
# 3  0.547772  0.421455  0.193280  2.177365
# 4  0.374704  0.632015  1.116807  0.833270

# %%
#apply默认作用在列上,x是每一列,因为axis=0
print(df.apply(lambda x : x.max()))
# Out:
# 0    0.547772
# 1    0.866597
# 2    1.116807
# 3    0.620086
# dtype: float64

# %%
#apply作用在行上
print(df.apply(lambda x : x.max(), axis=1))
# Out:
# 0   -0.122687
# 1    0.866597
# 2    0.620086
# 3    0.547772
# 4    1.116807
# dtype: float64

# %%
# 使用applymap应用到每个数据
print(df.map(lambda x : '%.2f' % x))
df.dtypes
# Out:
#        0      1      2      3
# 0  -0.46  -0.12  -1.13  -2.20
# 1  -0.85   0.87  -1.87  -1.28
# 2  -0.44  -1.24  -0.66   0.62
# 3   0.55  -0.42   0.19  -2.18
# 4  -0.37  -0.63   1.12  -0.83
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# dtype: object

# %%
type('%.2f' % 1.3456)
# Out:
# str

# %% [markdown]
# ## 6.4 索引排序（不重要）

# %%
# Series
print(np.random.randint(5, size=5))
print('-'*50)
s4 = pd.Series(range(10, 15), index = np.random.randint(5, size=5)) #索引随机生成
print(s4)
print('-'*50)
# 索引排序,sort_index返回一个新的排好索引的series
print(s4.sort_index())
print(s4)
# s4.loc[0:3]  loc索引值不唯一时直接报错
print(s4.iloc[0:3])
s4[0:3]  #默认用的位置索引
# Out:
# [3 3 1 2 3]
# --------------------------------------------------
# 3    10
# 1    11
# 3    12
# 1    13
# 3    14
# dtype: int64
# --------------------------------------------------
# 1    11
# 1    13
# 3    10
# 3    12
# 3    14
# dtype: int64
# 3    10
# 1    11
# 3    12
# 1    13
# 3    14
# dtype: int64
# 3    10
# 1    11
# 3    12
# dtype: int64
# 3    10
# 1    11
# 3    12
# dtype: int64

# %%
# s4.loc[1:2] #loc索引值唯一时可以切片

# %%
# DataFrame
df4 = pd.DataFrame(np.random.randn(5, 5),
                   index=np.random.randint(5, size=5),
                   columns=np.random.randint(5, size=5))
print(df4)
#轴零是行索引排序
df4_isort = df4.sort_index(axis=0, ascending=False)
print(df4_isort)
# Out:
#           3         3         2         1         3
# 2  2.001507 -0.851988  0.517658 -0.913286  0.046599
# 0  0.359916 -0.076158 -0.307362 -1.317722  1.372385
# 3  0.514004 -1.487974  0.573747  0.856009 -1.374626
# 0  0.187590  2.145109  0.721096 -1.018020  0.140337
# 0  0.694033  0.039258  0.490403 -0.472546 -1.157510
#           3         3         2         1         3
# 3  0.514004 -1.487974  0.573747  0.856009 -1.374626
# 2  2.001507 -0.851988  0.517658 -0.913286  0.046599
# 0  0.359916 -0.076158 -0.307362 -1.317722  1.372385
# 0  0.187590  2.145109  0.721096 -1.018020  0.140337
# 0  0.694033  0.039258  0.490403 -0.472546 -1.157510

# %%
#轴1是列索引排序
df4_isort = df4.sort_index(axis=1, ascending=True)
print(df4_isort)
# Out:
#           1         2         3         3         3
# 2 -0.913286  0.517658 -0.851988  2.001507  0.046599
# 0 -1.317722 -0.307362 -0.076158  0.359916  1.372385
# 3  0.856009  0.573747 -1.487974  0.514004 -1.374626
# 0 -1.018020  0.721096  2.145109  0.187590  0.140337
# 0 -0.472546  0.490403  0.039258  0.694033 -1.157510

# %% [markdown]
# # 6.5 按值排序（机器学习，深度学习不重要，数据分析才需要）

# %%
# 按值排序,by后是column的值
import random
l=[random.randint(0,100) for i in range(24)] #生成24个随机数
df4 = pd.DataFrame(np.array(l).reshape(6,4)) #生成6行4列的dataframe
# print(df4) #查看数据,ndarray
# print('-'*50)
print(df4)
print('-'*50)
#按轴零排序，by后是列名,交换的是行
df4_vsort = df4.sort_values(by=3,axis=0, ascending=False) #寻找的是columns里的3,重要
print(df4_vsort)
# Out:
#     0    1   2   3
# 0  30    3  38  56
# 1  44  100  96  55
# 2  61   39  64  93
# 3  71   63  23  93
# 4   8   52   9  15
# 5  34   52  16  19
# --------------------------------------------------
#     0    1   2   3
# 3  71   63  23  93
# 2  61   39  64  93
# 0  30    3  38  56
# 1  44  100  96  55
# 5  34   52  16  19
# 4   8   52   9  15

# %%
#按轴1排序，by后行索引名，交换的是列
df4_vsort = df4.sort_values(by=3,axis=1, ascending=False) #寻找的是index里的3
print(df4_vsort)
# Out:
#     3   0    1   2
# 0  56  30    3  38
# 1  55  44  100  96
# 2  93  61   39  64
# 3  93  71   63  23
# 4  15   8   52   9
# 5  19  34   52  16

# %% [markdown]
# # 6.6 处理缺失数据（重要）

# %%
df_data = pd.DataFrame([np.random.randn(3), [1., 2., np.nan],
                       [np.nan, 4., np.nan], [1., 2., 3.]])
print(df_data.head())
# Out:
#           0         1         2
# 0 -1.308007  0.242657  0.473588
# 1  1.000000  2.000000       NaN
# 2       NaN  4.000000       NaN
# 3  1.000000  2.000000  3.000000

# %%
df_data.iloc[2,0]
# Out:
# np.float64(nan)

# %%
#isnull来判断是否有空的数据
print(df_data.isnull())
# Out:
#        0      1      2
# 0  False  False  False
# 1  False  False   True
# 2   True  False   True
# 3  False  False  False

# %%
#帮我计算df_data缺失率
print(df_data.isnull().sum()/len(df_data))
# Out:
# 0    0.25
# 1    0.00
# 2    0.50
# dtype: float64

# %% [markdown]
# ## 删除缺失数据

# %%
#默认一个样本，任何一个特征缺失，就删除
#inplace True是修改的是原有的df
#subset=[0]是指按第一列来删除,第一列有空值就删除对应的行
print(df_data.dropna(subset=[0]))
# df_data
# Out:
#           0         1         2
# 0 -1.308007  0.242657  0.473588
# 1  1.000000  2.000000       NaN
# 3  1.000000  2.000000  3.000000

# %%
df_data
# Out:
#           0         1         2
# 0 -1.308007  0.242657  0.473588
# 1  1.000000  2.000000       NaN
# 2       NaN  4.000000       NaN
# 3  1.000000  2.000000  3.000000

# %%
#用的不多，用在某个特征缺失太多时，才会进行删除
print(df_data.dropna(axis=1))  #某列由nan就删除该列
# Out:
#           1
# 0  0.242657
# 1  2.000000
# 2  4.000000
# 3  2.000000

# %%
df_data
# Out:
#           0         1         2
# 0 -1.308007  0.242657  0.473588
# 1  1.000000  2.000000       NaN
# 2       NaN  4.000000       NaN
# 3  1.000000  2.000000  3.000000

# %% [markdown]
# ## 填充缺失数据

# %%
#均值，中位数，众数填充

# %%
#给零列的空值填为-100，按特征（按列）去填充
print(df_data.iloc[:,0].fillna(-100.))
df_data
# Out:
# 0     -1.308007
# 1      1.000000
# 2   -100.000000
# 3      1.000000
# Name: 0, dtype: float64
#           0         1         2
# 0 -1.308007  0.242657  0.473588
# 1  1.000000  2.000000       NaN
# 2       NaN  4.000000       NaN
# 3  1.000000  2.000000  3.000000

# %%
#依次拿到每一列
for i in df_data.columns:
    print(df_data.loc[:,i])
# Out:
# 0   -1.308007
# 1    1.000000
# 2         NaN
# 3    1.000000
# Name: 0, dtype: float64
# 0    0.242657
# 1    2.000000
# 2    4.000000
# 3    2.000000
# Name: 1, dtype: float64
# 0    0.473588
# 1         NaN
# 2         NaN
# 3    3.000000
# Name: 2, dtype: float64

# %%
df_data.iloc[:,0].fillna(-100.,inplace=True) #inplace=True后面会被删除
# Out:
# C:\Users\zack\AppData\Local\Temp\ipykernel_18828\2218614896.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df_data.iloc[:,0].fillna(-100.,inplace=True) #inplace=True后面会被删除
# 0     -1.308007
# 1      1.000000
# 2   -100.000000
# 3      1.000000
# Name: 0, dtype: float64

# %%
df_data.iloc[:,2]=df_data.iloc[:,2].fillna(df_data.iloc[:,2].mean()) #用均值填充空值

# %%
df_data
# Out:
#           0         1         2
# 0 -1.308007  0.242657  0.473588
# 1  1.000000  2.000000  1.736794
# 2       NaN  4.000000  1.736794
# 3  1.000000  2.000000  3.000000
